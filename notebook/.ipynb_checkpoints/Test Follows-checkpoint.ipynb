# %%
import polars as pl

# %%
pl.read_parquet("../output/follows/*.parquet")
# Out:
# shape: (1_768, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ did       ┆ handle    ┆ avatar    ┆ display_n ┆ … ┆ follows_h ┆ follows_a ┆ follows_d ┆ follows_ │
# │ ---       ┆ ---       ┆ ---       ┆ ame       ┆   ┆ andle     ┆ vatar     ┆ isplay_na ┆ descript │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ me        ┆ ion      │
# │           ┆           ┆           ┆ str       ┆   ┆ str       ┆ str       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ did:plc:u ┆ vincentga ┆ https://c ┆ Vincent   ┆ … ┆ vesteur.b ┆ https://c ┆ Christian ┆ CNRS res │
# │ qlu4scxbd ┆ uthier.bs ┆ dn.bsky.a ┆ Gauthier  ┆   ┆ sky.socia ┆ dn.bsky.a ┆ Vestergaa ┆ earcher  │
# ...
